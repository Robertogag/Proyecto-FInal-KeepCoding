# %%
import pandas as pd 
import numpy as np 
import xlsxwriter
import openpyxl 
import os 
from openpyxl import load_workbook
from pathlib import Path
import os
from openpyxl.styles import Font

# %% [markdown]
# # Iniciamos importando el reporte de Evidencias de GDR

# %%
dir_path = r"C:\Users\ZZJQC0\Documents\Base de Datos RV\Reportes\Global Damage Report GM EXPORTACIÓN - Autotech\EVIDENCIA DE DAÑOS"
df_list = []

def extraer_hipervinculos(ws, col_idx):
    links = []
    for row in ws.iter_rows(min_row=2, max_row=ws.max_row, min_col=col_idx, max_col=col_idx):
        cell = row[0]
        if cell.value is not None:
            link = cell.hyperlink.target if cell.hyperlink else None
            links.append(link)
        else:
            links.append(None)
    return links

def ajustar_longitud_hipervinculos(links, df_length):
    # Ajustar la longitud de los hipervínculos a la del DataFrame
    return links[:df_length] + [None] * (df_length - len(links))

for filename in os.listdir(dir_path):
    if filename.startswith("EVIDENCIA DE DAÑOS") and filename.endswith(".xlsx"):
        try:
            file_path = os.path.join(dir_path, filename)
            wb = load_workbook(file_path, data_only=True)
            ws = wb['REPARACIONES']
            df = pd.read_excel(file_path, sheet_name='REPARACIONES', engine='openpyxl')
            
            # Ajusta y asigna los hipervínculos
            df['Evidencia del Daño Link'] = ajustar_longitud_hipervinculos(extraer_hipervinculos(ws, 10), len(df))
            df['Evidencia del Daño.1 Link'] = ajustar_longitud_hipervinculos(extraer_hipervinculos(ws, 11), len(df))
            
            df_list.append(df)
            print(f"Procesado correctamente: {filename}")
        except Exception as e:
            print(f"Error procesando el archivo {filename}: {e}")

EvidenciasGDR = pd.concat(df_list, ignore_index=True)
# Out:
# Procesado correctamente: EVIDENCIA DE DAÑOS 02 04 2024.xlsx
# Error procesando el archivo EVIDENCIA DE DAÑOS 03 04 2024.xlsx: 'Worksheet REPARACIONES does not exist.'
# Procesado correctamente: EVIDENCIA DE DAÑOS 04 04 2024.xlsx
# Procesado correctamente: EVIDENCIA DE DAÑOS 06 04 2024.xlsx
# Procesado correctamente: EVIDENCIA DE DAÑOS 07 04 2024.xlsx
# Procesado correctamente: EVIDENCIA DE DAÑOS 08 04 2024.xlsx
# Procesado correctamente: EVIDENCIA DE DAÑOS 09 04 2024.xlsx
# Procesado correctamente: EVIDENCIA DE DAÑOS 10 04 2024.xlsx
# Procesado correctamente: EVIDENCIA DE DAÑOS 11 04 2024.xlsx
# Procesado correctamente: EVIDENCIA DE DAÑOS 13 04 2024.xlsx
# Error procesando el archivo EVIDENCIA DE DAÑOS 17 04 2024.xlsx: 'Worksheet REPARACIONES does not exist.'
# Error procesando el archivo EVIDENCIA DE DAÑOS 20 04 2024.xlsx: 'Worksheet REPARACIONES does not exist.'
# Error procesando el archivo EVIDENCIA DE DAÑOS 22 04 2024.xlsx: 'Worksheet REPARACIONES does not exist.'
# Procesado correctamente: EVIDENCIA DE DAÑOS 23 04 2024.xlsx
# Procesado correctamente: EVIDENCIA DE DAÑOS 24 04 2024.xlsx
# Procesado correctamente: EVIDENCIA DE DAÑOS 25 04 2024.xlsx
# Procesado correctamente: EVIDENCIA DE DAÑOS 26 04 2024.xlsx
# Error procesando el archivo EVIDENCIA DE DAÑOS 27 04 2024.xlsx: 'Worksheet REPARACIONES does not exist.'
# Procesado correctamente: EVIDENCIA DE DAÑOS 28 04 2024.xlsx
# Procesado correctamente: EVIDENCIA DE DAÑOS 29 04 2024.xlsx

# %% [markdown]
# **Eliminamos Columnas y limpiamos nombres de columnas:**

# %%
EvidenciasGDR.head()
# Out:
#        FECHA                VIN     MODELO DESTINO  AREA  DAÑO SEVERIDAD  \
# 0 2024-03-31  3GCNAAED7RG320283  SILVERADO     USA    61    30         -
# 1 2024-03-31  3GTUUCE81RG322094     SIERRA     USA    17    30         1
# 2 2024-04-03  3GNKBHR48RS211967     BLAZER  CANADA    62    30         -
# 3 2024-04-05  3GTPUCEK9RG208465     SIERRA     USA    62    30         -
# 4 2024-04-05  3GCPDDEK9RG325484  SILVERADO     USA    62    30         -
#
#                                          DESCRIPCION Responsable  \
# 0  INTERIOR DE LA CAJA. PICK-UP / MANCHADO O SUCI...         JCC
# 1  COSTADO / CUARTO DERECHO / MANCHADO O SUCIO EX...          TC
# 2  VEHICULO ENTERO / MANCHADO O SUCIO EXT. (FLUID...         JCC
# 3  VEHICULO ENTERO / MANCHADO O SUCIO EXT. (FLUID...       MARVA
# 4  VEHICULO ENTERO / MANCHADO O SUCIO EXT. (FLUID...          TC
#
#   Evidencia del Daño Evidencia del Daño.1 Evidencia de Reparacion  \
# 0         Ver Imagen           Ver Imagen              Ver Imagen
# 1         Ver Imagen           Ver Imagen                     NaN
# 2         Ver Imagen           Ver Imagen              Ver Imagen
# 3         Ver Imagen           Ver Imagen              Ver Imagen
# 4         Ver Imagen           Ver Imagen              Ver Imagen
#
#                        COMENTARIOS FECHA REPARACION  \
# 0  SE REALIZO LIMPIEZA DE EXTERIOR       2024-04-01
# 1     NO SE LOGRO QUITAR LA MANCHA       2024-04-01
# 2    SE REALIZO LAVADO CON SHAMPOO       2024-04-04
# 3    SE REALIZO LAVADO CON SHAMPOO       2024-04-06
# 4    SE REALIZO LAVADO CON SHAMPOO       2024-04-06
#
#                              Evidencia del Daño Link  \
# 0  http://vinfinder.jl.serv.net.mx/tracoImg/D_3GC...
# 1  http://vinfinder.jl.serv.net.mx/tracoImg/D_3GT...
# 2  http://vinfinder.jl.serv.net.mx/tracoImg/D_3GN...
# 3  http://vinfinder.jl.serv.net.mx/tracoImg/D_3GT...
# 4  http://vinfinder.jl.serv.net.mx/tracoImg/D_3GC...
#
#                            Evidencia del Daño.1 Link
# 0  http://vinfinder.jl.serv.net.mx/tracoImg/D_3GC...
# 1  http://vinfinder.jl.serv.net.mx/tracoImg/D_3GT...
# 2  http://vinfinder.jl.serv.net.mx/tracoImg/D_3GN...
# 3  http://vinfinder.jl.serv.net.mx/tracoImg/D_3GT...
# 4  http://vinfinder.jl.serv.net.mx/tracoImg/D_3GC...

# %%
# Eliminar espacios al principio y al final de los nombres de las columnas
EvidenciasGDR.columns = EvidenciasGDR.columns.str.strip()

# %% [markdown]
# **Eliminar columnas**

# %%
EvidenciasGDR.columns
# Out:
# Index(['FECHA', 'VIN', 'MODELO', 'DESTINO', 'AREA', 'DAÑO', 'SEVERIDAD',
#        'DESCRIPCION', 'Responsable', 'Evidencia del Daño',
#        'Evidencia del Daño.1', 'Evidencia de Reparacion', 'COMENTARIOS',
#        'FECHA REPARACION', 'Evidencia del Daño Link',
#        'Evidencia del Daño.1 Link'],
#       dtype='object')

# %% [markdown]
# ### Guardamos el DF y nos aseguramos que los Hipervinculos funcionen:

# %%
# Define las columnas que deseas conservar
columnas_conservar = ['VIN', 'Evidencia del Daño Link', 'Evidencia del Daño.1 Link']

# Selecciona solo las columnas deseadas del DataFrame
EvidenciasGDR = EvidenciasGDR[columnas_conservar]

# %%
EvidenciasGDR.head()
# Out:
#                  VIN                            Evidencia del Daño Link  \
# 0  3GCNAAED7RG320283  http://vinfinder.jl.serv.net.mx/tracoImg/D_3GC...
# 1  3GTUUCE81RG322094  http://vinfinder.jl.serv.net.mx/tracoImg/D_3GT...
# 2  3GNKBHR48RS211967  http://vinfinder.jl.serv.net.mx/tracoImg/D_3GN...
# 3  3GTPUCEK9RG208465  http://vinfinder.jl.serv.net.mx/tracoImg/D_3GT...
# 4  3GCPDDEK9RG325484  http://vinfinder.jl.serv.net.mx/tracoImg/D_3GC...
#
#                            Evidencia del Daño.1 Link
# 0  http://vinfinder.jl.serv.net.mx/tracoImg/D_3GC...
# 1  http://vinfinder.jl.serv.net.mx/tracoImg/D_3GT...
# 2  http://vinfinder.jl.serv.net.mx/tracoImg/D_3GN...
# 3  http://vinfinder.jl.serv.net.mx/tracoImg/D_3GT...
# 4  http://vinfinder.jl.serv.net.mx/tracoImg/D_3GC...

# %%
# Guarda el DataFrame a CSV
ruta_csv = r'C:\Users\ZZJQC0\Documents\Base de Datos RV\Base de Datos\EvidenciasReparaciones.csv'


EvidenciasGDR.to_csv(ruta_csv, index=False, encoding='utf-8-sig', sep=';')
